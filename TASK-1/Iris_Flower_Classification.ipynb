# %% [markdown]
# # CIPHERBYTE ML INTERNSHIP

# %% [markdown]
# ### TASK-1 : IRIS FLOWER CLASSIFICATION
# BY SATTWIKEE GHOSH

# %% [markdown]
# **Importing The Important Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn import metrics
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

# %%
from google.colab import files
data=files.upload()
# Out:
#      <input type="file" id="files-199b4e2f-fd12-4aa8-8507-9b60bdbda56b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-199b4e2f-fd12-4aa8-8507-9b60bdbda56b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Import The Iris Dataset**

# %%
df=pd.read_csv('Iris Flower - Iris.csv')

# %% [markdown]
# **Data Exploration**

# %%
# Checking the first 5 rows
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# Checking the last 5 rows
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.shape
# Out:
# (150, 6)

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data=df.groupby('Species')

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# **Getting a descriptive statistics summary of the dataset**

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# **Finding Out Co-Relation**

# %%
corr=df.corr()
corr
# Out:
# <ipython-input-101-7d5195e2bf4d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
#
#                PetalWidthCm
# Id                 0.899759
# SepalLengthCm      0.817954
# SepalWidthCm      -0.356544
# PetalLengthCm      0.962757
# PetalWidthCm       1.000000

# %% [markdown]
# **HEAT MAP**

# %%
plt.figure(figsize=(10,7))
sns.heatmap(df.corr(), annot = True, cmap = "Oranges_r")
plt.show()
# Out:
# <ipython-input-102-bfea0be3b343>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot = True, cmap = "Oranges_r")

# %% [markdown]
# **DATA VISUALISATION**

# %% [markdown]
# **Line Chart**

# %%
# Creating line chart
plt.plot(df['SepalLengthCm'], label='Sepal_Length')
plt.plot(df['SepalWidthCm'], label='Sepal_Width')
plt.plot(df['PetalLengthCm'], label='Petal_Length')
plt.plot(df['PetalWidthCm'], label='Petal_Width')

# Adding labels and titles
plt.xlabel('Sample')
plt.ylabel('Measurement')
plt.title('Line Chart - Iris Dataset')

# Adding Legend
plt.legend()

# Displaying the line chart
plt.show()

# %% [markdown]
# **Strip Plot**

# %%
# Creating strip plot
sns.stripplot(x='Species', y='SepalLengthCm',data=df)

# Adding labels and title
plt.xlabel('Species')
plt.ylabel('Sepal_Length')
plt.title('Strip Plot - Iris Dataset')

# Displaying the Strip Plot
plt.show()

# %% [markdown]
# **Box Plot**

# %%
# Creating a Box_Plot
sns.boxplot(x='Species', y='SepalWidthCm', data=df)

# Adding labels and title
plt.xlabel('Species')
plt.ylabel('Sepal_Width')
plt.title('Box Plot - Iris Dataset')

# Displaying the Box_Plot
plt.show()

# %% [markdown]
# **Count Plot**

# %%
# Creating a Count_Plot
sns.countplot(data=df, x="Species")

# Adding labels and title
plt.xlabel('Species')
plt.ylabel('Count')
plt.title("Species Distribution - Count_Plot")

# Displaying the Count_Plot
plt.show()

# %% [markdown]
# **Joint Plot (For SepalLength and SepalWidth)**

# %%
# Creating a Joint_Plot
sns.jointplot(data=df, x='SepalLengthCm', y='SepalWidthCm')


# Displaying the Joint_Plot
plt.show()

# %% [markdown]
# **Joint Plot (For PetalLength and PetalWidth)**

# %%
# Creating a Joint_Plot
sns.jointplot(data=df, x='PetalLengthCm', y='PetalWidthCm')


# Displaying the Joint_Plot
plt.show()

# %% [markdown]
# **Bar Plot (For SepalLength)**

# %%
# Creating a Bar_Plot
sns.barplot(data=df, x='Species',y='SepalLengthCm')

# Adding labels and title
plt.xlabel("Species")
plt.ylabel("Sepal_Length_Cm")
plt.title("Sepal Length Of Species - Bar Plot")

# Displaying the Bar_Plot
plt.show()

# %% [markdown]
# **Bar Plot (For PetalLength)**

# %%
# Creating a Bar_Plot
sns.barplot(data=df, x='Species',y='PetalLengthCm')

# Adding labels and title
plt.xlabel("Species")
plt.ylabel("Petal_Length_Cm")
plt.title("Petal Length Of Species - Bar Plot")

# Displaying the Bar_Plot
plt.show()

# %% [markdown]
# **Scatter Plot - Sepal_Length VS Sepal_Width**

# %%
# Creating a Scatter Plot
sns.scatterplot(data=df, x='SepalLengthCm', y='SepalWidthCm', hue='Species')

# Adding labels and titles
plt.xlabel("Sepal_Length_Cm")
plt.ylabel("Sepal_Width_Cm")
plt.title("Scatter Plot - Sepal_Length VS Sepal_Width")

# Displaying the Scatter_Plot
plt.show()

# %% [markdown]
# **Scatter Plot - Sepal_Length VS Petal_Width**

# %%
# Creating a Scatter Plot
sns.scatterplot(data=df, x='SepalLengthCm', y='PetalWidthCm', hue='Species')

# Adding labels and titles
plt.xlabel("Sepal_Length_Cm")
plt.ylabel("Petal_Width_Cm")
plt.title("Scatter Plot - Sepal_Length VS Petal_Width")

# Displaying the Scatter_Plot
plt.show()

# %% [markdown]
# **Categorical Plot (For SepalLength)**

# %%
# Creating a Categorical Plot
sns.catplot(x='Species', y='SepalLengthCm', data=df, kind='swarm')

# Adding labels and titles
plt.xlabel("Species")
plt.ylabel("Sepal_Length_Cm")
plt.title("Categorical Plot - Iris Dataset")

# Displaying the Categorical_Plot
plt.show()

# %% [markdown]
# **Categorical Plot (For PetalLength)**

# %%
# Creating a Categorical Plot
sns.catplot(x='Species', y='PetalLengthCm', data=df, kind='swarm')

# Adding labels and titles
plt.xlabel("Species")
plt.ylabel("Petal_Length_Cm")
plt.title("Categorical Plot - Iris Dataset")

# Displaying the Categorical_Plot
plt.show()

# %% [markdown]
# **Violin Plot**

# %%
# Creating a Violin Plot
sns.violinplot(x='Species', y='SepalLengthCm', data=df)

# Adding labels and titles
plt.xlabel("Species")
plt.ylabel("Sepal_Length_Cm")
plt.title("Violin Plot - Iris Dataset")

# Displaying the Violin_Plot
plt.show()

# %% [markdown]
# **Lmplot**

# %%
sns.lmplot(x="SepalLengthCm", y="SepalWidthCm", data=df, hue= 'Species', legend = False)
plt.legend(["Sepal_Length_Cm","Sepal_Width_Cm"])

# %%
a = sns.FacetGrid(df,col = 'Species')
a.map(plt.scatter,'SepalLengthCm','SepalWidthCm')

# %% [markdown]
# **DATA PREPROCESSING**

# %%
df.drop('Id',axis=1,inplace=True)

# %% [markdown]
# **Tranforming Categorical Data Into Numerical Values**

# %%
sp={'Iris-setosa':1,'Iris-versicolor':2,'Iris-virginica':3}
df.Species=[sp[i] for i in df.Species]

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0            5.1           3.5            1.4           0.2        1
# 1            4.9           3.0            1.4           0.2        1
# 2            4.7           3.2            1.3           0.2        1
# 3            4.6           3.1            1.5           0.2        1
# 4            5.0           3.6            1.4           0.2        1

# %%
X=df.iloc[:,0:4]

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
Y=df.iloc[:,4]

# %%
Y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Species, Length: 150, dtype: int64

# %% [markdown]
# **MODEL BUILDING**

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20,random_state=50)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
Y_train.shape
# Out:
# (120,)

# %%
X_test.shape
# Out:
# (30, 4)

# %%
Y_test.shape
# Out:
# (30,)

# %% [markdown]
# **K - NEAREST NEIGHBOUR**

# %%
k=5
knclr=KNeighborsClassifier(k)

# %%
knclr
# Out:
# KNeighborsClassifier()

# %%
knclr.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred=knclr.predict(X_test)

# %%
cm = metrics.confusion_matrix(Y_test, y_pred)
print("Confusion Matrix :")
cm
# Out:
# Confusion Matrix :
# array([[9, 0, 0],
#        [0, 9, 3],
#        [0, 0, 9]])

# %%
acc = metrics.accuracy_score(Y_test, y_pred)*100
print("Accuracy Score :")
acc
# Out:
# Accuracy Score :
# 90.0

# %%
print("Classification Report :")
print(metrics.classification_report(Y_test, y_pred))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      0.75      0.86        12
#            3       0.75      1.00      0.86         9
#
#     accuracy                           0.90        30
#    macro avg       0.92      0.92      0.90        30
# weighted avg       0.93      0.90      0.90        30

# %%
print("Mean squared error: %.2f" % np.mean((y_pred - Y_test) ** 2))
# Out:
# Mean squared error: 0.10

# %% [markdown]
# **LOGISTIC REGRESSION**

# %%
lr = LogisticRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
Y_pred = lr.predict(X_test)

# %%
cm = metrics.confusion_matrix(Y_test, Y_pred)
print("Confusion Matrix :")
cm
# Out:
# Confusion Matrix :
# array([[ 9,  0,  0],
#        [ 0, 11,  1],
#        [ 0,  0,  9]])

# %%
acc = metrics.accuracy_score(Y_test, Y_pred)*100
print("Accuracy Score :")
acc
# Out:
# Accuracy Score :
# 96.66666666666667

# %%
print("Classification Report :")
print(metrics.classification_report(Y_test, Y_pred))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      0.92      0.96        12
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
print("Mean squared error: %.2f" % np.mean((Y_pred - Y_test) ** 2))
# Out:
# Mean squared error: 0.03

# %% [markdown]
# **RANDOM FOREST CLASSIFIER**

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
Y_Pred = rfc.predict(X_test)

# %%
cm = metrics.confusion_matrix(Y_test, Y_Pred)
print("Confusion Matrix :")
cm
# Out:
# Confusion Matrix :
# array([[ 9,  0,  0],
#        [ 0, 11,  1],
#        [ 0,  0,  9]])

# %%
acc = metrics.accuracy_score(Y_test, Y_Pred)*100
print("Accuracy Score :")
acc
# Out:
# Accuracy Score :
# 96.66666666666667

# %%
print("Classification Report :")
print(metrics.classification_report(Y_test, Y_Pred))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      0.92      0.96        12
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
print("Mean squared error: %.2f" % np.mean((Y_Pred - Y_test) ** 2))
# Out:
# Mean squared error: 0.03

# %% [markdown]
# **DECISION TREE**

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_Pred = dt.predict(X_test)

# %%
cm = metrics.confusion_matrix(Y_test, y_Pred)
print("Confusion Matrix :")
cm
# Out:
# Confusion Matrix :
# array([[ 9,  0,  0],
#        [ 0, 11,  1],
#        [ 0,  0,  9]])

# %%
acc = metrics.accuracy_score(Y_test, y_Pred)*100
print("Accuracy Score :")
acc
# Out:
# Accuracy Score :
# 96.66666666666667

# %%
print("Classification Report :")
print(metrics.classification_report(Y_test, y_Pred))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      0.92      0.96        12
#            3       0.90      1.00      0.95         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30

# %%
print("Mean squared error: %.2f" % np.mean((y_Pred - Y_test) ** 2))
# Out:
# Mean squared error: 0.03

# %%
from sklearn.tree import plot_tree
feature = ["SepalLengthCm", "SepalWidthCm", "PetalLengthCm", "PetalWidthCm"]
classes = ["Iris-Setosa", "Iris-Versicolor", "Iris-Virginica"]
plt.figure(figsize=(10,10))
plot_tree(dt, feature_names = feature, class_names = classes, filled = True);

# %% [markdown]
# **SUPPORT VECTOR MACHINE**

# %%
svc = SVC()

# %%
svc.fit(X_train, Y_train)
# Out:
# SVC()

# %%
y_PRed = svc.predict(X_test)

# %%
cm = metrics.confusion_matrix(Y_test, y_PRed)
print("Confusion Matrix :")
cm
# Out:
# Confusion Matrix :
# array([[ 9,  0,  0],
#        [ 0, 10,  2],
#        [ 0,  0,  9]])

# %%
acc = metrics.accuracy_score(Y_test, y_PRed)*100
print("Accuracy Score :")
acc
# Out:
# Accuracy Score :
# 93.33333333333333

# %%
print("Classification Report :")
print(metrics.classification_report(Y_test, y_PRed))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      0.83      0.91        12
#            3       0.82      1.00      0.90         9
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.95      0.93      0.93        30

# %%
print("Mean squared error: %.2f" % np.mean((y_PRed - Y_test) ** 2))
# Out:
# Mean squared error: 0.07

# %% [markdown]
# **NAIVE BAYES CLASSIFIER**

# %%
nb = GaussianNB()

# %%
nb.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %%
y_prEd = nb.predict(X_test)

# %%
cm = metrics.confusion_matrix(Y_test, y_prEd)
print("Confusion Matrix :")
cm
# Out:
# Confusion Matrix :
# array([[ 9,  0,  0],
#        [ 0, 10,  2],
#        [ 0,  0,  9]])

# %%
acc = metrics.accuracy_score(Y_test, y_prEd)*100
print("Accuracy Score :")
acc
# Out:
# Accuracy Score :
# 93.33333333333333

# %%
print("Classification Report :")
print(metrics.classification_report(Y_test, y_prEd))
# Out:
# Classification Report :
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00         9
#            2       1.00      0.83      0.91        12
#            3       0.82      1.00      0.90         9
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.95      0.93      0.93        30

# %%
print("Mean squared error: %.2f" % np.mean((y_prEd - Y_test) ** 2))
# Out:
# Mean squared error: 0.07

# %% [markdown]
# **TESTING THE MODEL**

# %%
input = (6.3,3.3,6.0,2.5)
input_to_arr = np.asarray(input)
input_reshaped = input_to_arr.reshape(1,-1)
pred = rfc.predict(input_reshaped)
print("The above input falls under the specified category :",pred)
# Out:
# The above input falls under the specified category : [3]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
